# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../csv/results.csv')

# %%
data.head()
# Out:
#   lang       compiler  exec time (s)  mem consump (kb)  bin size (kb)  loc
# 0    C    gcc v11.1.0            9.2               340            8.8   83
# 1    C  clang v11.0.0           11.3               900            8.8   83
# 2  C++    gcc v11.1.0           46.8              1500           15.0   84
# 3  C++  clang v11.0.0           11.7               832           15.9   84
# 4    D   dmd v2.097.1           97.6              2000         1270.0   81

# %%
data['lang && compiler'] = data['lang'] + ' ' + data['compiler']

# %%
data.head(len(data))
# Out:
#          lang       compiler  exec time (s)  mem consump (kb)  bin size (kb)  \
# 0           C    gcc v11.1.0           9.20               340            8.8
# 1           C  clang v11.0.0          11.30               900            8.8
# 2         C++    gcc v11.1.0          46.80              1500           15.0
# 3         C++  clang v11.0.0          11.70               832           15.9
# 4           D   dmd v2.097.1          97.60              2000         1270.0
# 5           D    gdc v11.1.0         195.00              2300          229.4
# 6           D    ldc v1.27.0          50.40              5000         6175.0
# 7        Rust  rustc v1.51.0          13.00               264          459.8
# 8      Python         v3.9.6         466.50             35300            0.0
# 9          R          v4.1.0         481.82             48500            0.0
# 10     D nogc   dmd v2.097.1          48.00               460          829.8
# 11     D nogc    gdc v11.1.0         150.20               968           95.7
# 12     D nogc    ldc v1.27.0          30.80               636         6155.0
# 13  D betterC   dmd v2.097.1          23.20               340           10.2
# 14  D betterC    gdc v11.1.0          12.90               360           10.4
# 15  D betterC    ldc v1.27.0          10.40               340           14.0
#
#     loc        lang && compiler
# 0    83           C gcc v11.1.0
# 1    83         C clang v11.0.0
# 2    84         C++ gcc v11.1.0
# 3    84       C++ clang v11.0.0
# 4    81          D dmd v2.097.1
# 5    81           D gdc v11.1.0
# 6    81           D ldc v1.27.0
# 7   118      Rust rustc v1.51.0
# 8    22           Python v3.9.6
# 9    18               R  v4.1.0
# 10   86     D nogc dmd v2.097.1
# 11   86      D nogc gdc v11.1.0
# 12   86      D nogc ldc v1.27.0
# 13   88  D betterC dmd v2.097.1
# 14   88   D betterC gdc v11.1.0
# 15   88   D betterC ldc v1.27.0

# %%
data = data.sort_values(ascending=True, by='exec time (s)').reset_index(drop=True)
data.head(len(data))
# Out:
#          lang       compiler  exec time (s)  mem consump (kb)  bin size (kb)  \
# 0           C    gcc v11.1.0           9.20               340            8.8
# 1   D betterC    ldc v1.27.0          10.40               340           14.0
# 2           C  clang v11.0.0          11.30               900            8.8
# 3         C++  clang v11.0.0          11.70               832           15.9
# 4   D betterC    gdc v11.1.0          12.90               360           10.4
# 5        Rust  rustc v1.51.0          13.00               264          459.8
# 6   D betterC   dmd v2.097.1          23.20               340           10.2
# 7      D nogc    ldc v1.27.0          30.80               636         6155.0
# 8         C++    gcc v11.1.0          46.80              1500           15.0
# 9      D nogc   dmd v2.097.1          48.00               460          829.8
# 10          D    ldc v1.27.0          50.40              5000         6175.0
# 11          D   dmd v2.097.1          97.60              2000         1270.0
# 12     D nogc    gdc v11.1.0         150.20               968           95.7
# 13          D    gdc v11.1.0         195.00              2300          229.4
# 14     Python         v3.9.6         466.50             35300            0.0
# 15         R          v4.1.0         481.82             48500            0.0
#
#     loc        lang && compiler
# 0    83           C gcc v11.1.0
# 1    88   D betterC ldc v1.27.0
# 2    83         C clang v11.0.0
# 3    84       C++ clang v11.0.0
# 4    88   D betterC gdc v11.1.0
# 5   118      Rust rustc v1.51.0
# 6    88  D betterC dmd v2.097.1
# 7    86      D nogc ldc v1.27.0
# 8    84         C++ gcc v11.1.0
# 9    86     D nogc dmd v2.097.1
# 10   81           D ldc v1.27.0
# 11   81          D dmd v2.097.1
# 12   86      D nogc gdc v11.1.0
# 13   81           D gdc v11.1.0
# 14   22           Python v3.9.6
# 15   18               R  v4.1.0

# %%
X = data['lang && compiler']
Y = data['exec time (s)']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = Y)
plt.xticks(rotation = 90)

for i in range(len(Y)):
    plt.text(i, Y[i], Y[i], ha = 'center')

fig.savefig('../plots/exec_time.jpg', bbox_inches = 'tight')

# %%
data2 = data.drop(data.index[[14, 15]]).reset_index(drop=True).sort_values(ascending=True, by='mem consump (kb)').reset_index(drop=True)
data2.head(len(data2))
# Out:
#          lang       compiler  exec time (s)  mem consump (kb)  bin size (kb)  \
# 0        Rust  rustc v1.51.0           13.0               264          459.8
# 1           C    gcc v11.1.0            9.2               340            8.8
# 2   D betterC    ldc v1.27.0           10.4               340           14.0
# 3   D betterC   dmd v2.097.1           23.2               340           10.2
# 4   D betterC    gdc v11.1.0           12.9               360           10.4
# 5      D nogc   dmd v2.097.1           48.0               460          829.8
# 6      D nogc    ldc v1.27.0           30.8               636         6155.0
# 7         C++  clang v11.0.0           11.7               832           15.9
# 8           C  clang v11.0.0           11.3               900            8.8
# 9      D nogc    gdc v11.1.0          150.2               968           95.7
# 10        C++    gcc v11.1.0           46.8              1500           15.0
# 11          D   dmd v2.097.1           97.6              2000         1270.0
# 12          D    gdc v11.1.0          195.0              2300          229.4
# 13          D    ldc v1.27.0           50.4              5000         6175.0
#
#     loc        lang && compiler
# 0   118      Rust rustc v1.51.0
# 1    83           C gcc v11.1.0
# 2    88   D betterC ldc v1.27.0
# 3    88  D betterC dmd v2.097.1
# 4    88   D betterC gdc v11.1.0
# 5    86     D nogc dmd v2.097.1
# 6    86      D nogc ldc v1.27.0
# 7    84       C++ clang v11.0.0
# 8    83         C clang v11.0.0
# 9    86      D nogc gdc v11.1.0
# 10   84         C++ gcc v11.1.0
# 11   81          D dmd v2.097.1
# 12   81           D gdc v11.1.0
# 13   81           D ldc v1.27.0

# %%
X = data2['lang && compiler']
Y = data2['mem consump (kb)']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = Y)
plt.xticks(rotation = 90)

for i in range(len(Y)):
    plt.text(i, Y[i], Y[i], ha = 'center')

fig.savefig('../plots/mem_consump.jpg', bbox_inches = 'tight')

# %%
data2 = data2.sort_values(ascending=True, by='bin size (kb)').reset_index(drop=True)
data2.head(len(data2))
# Out:
#          lang       compiler  exec time (s)  mem consump (kb)  bin size (kb)  \
# 0           C    gcc v11.1.0            9.2               340            8.8
# 1           C  clang v11.0.0           11.3               900            8.8
# 2   D betterC   dmd v2.097.1           23.2               340           10.2
# 3   D betterC    gdc v11.1.0           12.9               360           10.4
# 4   D betterC    ldc v1.27.0           10.4               340           14.0
# 5         C++    gcc v11.1.0           46.8              1500           15.0
# 6         C++  clang v11.0.0           11.7               832           15.9
# 7      D nogc    gdc v11.1.0          150.2               968           95.7
# 8           D    gdc v11.1.0          195.0              2300          229.4
# 9        Rust  rustc v1.51.0           13.0               264          459.8
# 10     D nogc   dmd v2.097.1           48.0               460          829.8
# 11          D   dmd v2.097.1           97.6              2000         1270.0
# 12     D nogc    ldc v1.27.0           30.8               636         6155.0
# 13          D    ldc v1.27.0           50.4              5000         6175.0
#
#     loc        lang && compiler
# 0    83           C gcc v11.1.0
# 1    83         C clang v11.0.0
# 2    88  D betterC dmd v2.097.1
# 3    88   D betterC gdc v11.1.0
# 4    88   D betterC ldc v1.27.0
# 5    84         C++ gcc v11.1.0
# 6    84       C++ clang v11.0.0
# 7    86      D nogc gdc v11.1.0
# 8    81           D gdc v11.1.0
# 9   118      Rust rustc v1.51.0
# 10   86     D nogc dmd v2.097.1
# 11   81          D dmd v2.097.1
# 12   86      D nogc ldc v1.27.0
# 13   81           D ldc v1.27.0

# %%
X = data2['lang && compiler']
Y = data2['bin size (kb)']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = np.log(Y))
plt.xticks(rotation = 90)

for i in range(len(Y)):
    plt.text(i, np.log(Y[i]), Y[i], ha = 'center')

fig.savefig('../plots/bin_size.jpg', bbox_inches = 'tight')

# %%
X = data2['lang']
Y = data2['mem consump (kb)']
Z = data2['compiler']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = Y, hue = Z)
plt.xticks(rotation = 90)

#for i in range(len(Y)):
#    plt.text(i, np.log(Y[i]), Y[i], ha = 'center')

fig.savefig('../plots/mem_consump_compiler-wise.jpg', bbox_inches = 'tight')

# %%
X = data2['lang']
Y = data2['exec time (s)']
Z = data2['compiler']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = Y, hue = Z)
plt.xticks(rotation = 90)

#for i in range(len(Y)):
#    plt.text(i, np.log(Y[i]), Y[i], ha = 'center')

fig.savefig('../plots/exec_time_compiler-wise.jpg', bbox_inches = 'tight')

# %%
X = data2['lang']
Y = data2['loc']

# setting plot size
fig = plt.figure(figsize = (12, 7))
sns.set_theme(style="whitegrid")

# plotting
sns.barplot(x = X, y = Y)
plt.xticks(rotation = 90)

#for i in range(len(Y)):
#    plt.text(i, np.log(Y[i]), Y[i], ha = 'center')

fig.savefig('../plots/loc.jpg', bbox_inches = 'tight')
